# %% [markdown]
# # DUCK CURVE for different seasons for India #

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from timezonefinder import TimezoneFinder
import pvlib
from pvlib.location import Location
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates

# %% [markdown]
# ### WINTER (15 January) ###

# %%
df1 = pd.read_excel(r"D:\IIT BOMBAY\April 2025\Duck_Curve\Indian_duck_curve_15_Jan.xlsx")
df1.head()
# Out:
#        time  demand_2020  poa_2020  Ins_Cap_Dec_2019  solar_2020  \
# 0  00:00:00    117049.69       0.0          33730.56         0.0
# 1  01:00:00    113503.22       0.0          33730.56         0.0
# 2  02:00:00    111439.14       0.0          33730.56         0.0
# 3  03:00:00    111000.05       0.0          33730.56         0.0
# 4  04:00:00    113620.60       0.0          33730.56         0.0
#
#    Net_Load_2020  demand_2021  poa_2021  Ins_Cap_Dec_2020  solar_2021  ...  \
# 0      117049.69    117613.25       0.0          37464.64         0.0  ...
# 1      113503.22    114797.12       0.0          37464.64         0.0  ...
# 2      111439.14    112761.61       0.0          37464.64         0.0  ...
# 3      111000.05    112362.40       0.0          37464.64         0.0  ...
# 4      113620.60    114555.60       0.0          37464.64         0.0  ...
#
#    demand_2023  poa_2023  Ins_Cap_Dec_2022  solar_2023  Net_Load_2023  \
# ...

# %%
# Convert 'Hour' column to proper time format
df1.index = pd.to_datetime(df1["time"], format='%H:%M:%S')

fig, ax = plt.subplots(figsize=(10, 5))

plt.plot(df1.index, df1["Net_Load_2020"], label="2020", color="black", marker="P", linestyle="-")
plt.plot(df1.index, df1["Net_Load_2021"], label="2021", color="yellow", marker="x", linestyle="-")
plt.plot(df1.index, df1["Net_Load_2022"], label="2022", color="blue", marker="o", linestyle="-")
plt.plot(df1.index, df1["Net_Load_2023"], label="2023", color="red", marker="s", linestyle="-")
plt.plot(df1.index, df1["Net_Load_2024"], label="2024", color="green", marker="^", linestyle="-")

date_form = DateFormatter('%H:%M')
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.HourLocator(interval=2))

# Formatting the plot
plt.xlabel("Hour of the Day", fontsize=12)
plt.ylabel("Net Load (MW)", fontsize=12)
plt.title("Duck Curve for India (Winter season)", fontsize=16, weight= "bold")
#plt.xticks(range(0, 24, 1))
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# ### SUMMER (15 June) ###

# %%
df2 = pd.read_excel(r"D:\IIT BOMBAY\April 2025\Duck_Curve\Indian_duck_curve_15_Jun.xlsx")
df2.head()
# Out:
#        time  demand_2020  poa_2020  Ins_Cap_May_2020  solar_2020  \
# 0  00:00:00    150228.10       0.0          34955.48         0.0
# 1  01:00:00    146217.17       0.0          34955.48         0.0
# 2  02:00:00    142262.74       0.0          34955.48         0.0
# 3  03:00:00    139186.56       0.0          34955.48         0.0
# 4  04:00:00    138384.77       0.0          34955.48         0.0
#
#    Net_Load_2020  demand_2021  poa_2021  Ins_Cap_May_2021  solar_2021  ...  \
# 0      150228.10    159275.04       0.0          41087.63         0.0  ...
# 1      146217.17    154626.47       0.0          41087.63         0.0  ...
# 2      142262.74    150757.91       0.0          41087.63         0.0  ...
# 3      139186.56    147722.71       0.0          41087.63         0.0  ...
# 4      138384.77    146267.22       0.0          41087.63         0.0  ...
#
#    demand_2022  poa_2022  Ins_Cap_May_2022  solar_2022  Net_Load_2022  \
# ...

# %%
# Convert 'Hour' column to proper time format
df2.index = pd.to_datetime(df2["time"], format='%H:%M:%S')

fig, ax = plt.subplots(figsize=(10, 5))

plt.plot(df2.index, df2["Net_Load_2020"], label="2020", color="black", marker="P", linestyle="-")
plt.plot(df2.index, df2["Net_Load_2021"], label="2021", color="yellow", marker="x", linestyle="-")
plt.plot(df2.index, df2["Net_Load_2022"], label="2022", color="blue", marker="o", linestyle="-")
plt.plot(df2.index, df2["Net_Load_2023"], label="2023", color="red", marker="s", linestyle="-")

date_form = DateFormatter('%H:%M')
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.HourLocator(interval=2))

# Formatting the plot
plt.xlabel("Hour of the Day", fontsize=12)
plt.ylabel("Net Load (MW)", fontsize=12)
plt.title("Duck Curve for India (Summer season)", fontsize=16, weight= "bold")
#plt.xticks(range(0, 24, 1))
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# ### MONSOON (15 August) ###

# %%
df3 = pd.read_excel(r"D:\IIT BOMBAY\April 2025\Duck_Curve\Indian_duck_curve_15_Aug.xlsx")
df3.head()
# Out:
#        time  demand_2020  poa_2020  Ins_Cap_Jul_2020  solar_2020  \
# 0  00:00:00    144956.43       0.0          35739.35         0.0
# 1  01:00:00    141296.03       0.0          35739.35         0.0
# 2  02:00:00    138248.60       0.0          35739.35         0.0
# 3  03:00:00    135764.75       0.0          35739.35         0.0
# 4  04:00:00    134939.84       0.0          35739.35         0.0
#
#    Net_Load_2020  demand_2021  poa_2021  Ins_Cap_Jul_2021  solar_2021  ...  \
# 0      144956.43    182249.09       0.0          43940.12         0.0  ...
# 1      141296.03    178875.96       0.0          43940.12         0.0  ...
# 2      138248.60    175480.91       0.0          43940.12         0.0  ...
# 3      135764.75    172833.20       0.0          43940.12         0.0  ...
# 4      134939.84    172001.80       0.0          43940.12         0.0  ...
#
#    demand_2022  poa_2022  Ins_Cap_Jul_2022  solar_2022  Net_Load_2022  \
# ...

# %%
# Convert 'Hour' column to proper time format
df3.index = pd.to_datetime(df3["time"], format='%H:%M:%S')

fig, ax = plt.subplots(figsize=(10, 5))

plt.plot(df3.index, df3["Net_Load_2020"], label="2020", color="black", marker="P", linestyle="-")
plt.plot(df3.index, df3["Net_Load_2021"], label="2021", color="yellow", marker="x", linestyle="-")
plt.plot(df3.index, df3["Net_Load_2022"], label="2022", color="blue", marker="o", linestyle="-")
plt.plot(df3.index, df3["Net_Load_2023"], label="2023", color="red", marker="s", linestyle="-")

date_form = DateFormatter('%H:%M')
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.HourLocator(interval=2))

# Formatting the plot
plt.xlabel("Hour of the Day", fontsize=12)
plt.ylabel("Net Load (MW)", fontsize=12)
plt.title("Duck Curve for India (Monsoon season)", fontsize=16, weight= "bold")
#plt.xticks(range(0, 24, 1))
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# ### POST- MONSOON (15 October) ###

# %%
df4 = pd.read_excel(r"D:\IIT BOMBAY\April 2025\Duck_Curve\Indian_duck_curve_15_Oct.xlsx")
df4.head()
# Out:
#        time  demand_2020  poa_2020  Ins_Cap_Sep_2020  solar_2020  \
# 0  00:00:00    144801.75       0.0          36050.74         0.0
# 1  01:00:00    141921.70       0.0          36050.74         0.0
# 2  02:00:00    138772.14       0.0          36050.74         0.0
# 3  03:00:00    136963.40       0.0          36050.74         0.0
# 4  04:00:00    136857.86       0.0          36050.74         0.0
#
#    Net_Load_2020  demand_2021  poa_2021  Ins_Cap_Sep_2021  solar_2021  ...  \
# 0      144801.75    151810.29       0.0          46275.14         0.0  ...
# 1      141921.70    149214.07       0.0          46275.14         0.0  ...
# 2      138772.14    146682.12       0.0          46275.14         0.0  ...
# 3      136963.40    144760.43       0.0          46275.14         0.0  ...
# 4      136857.86    144224.60       0.0          46275.14         0.0  ...
#
#    demand_2022  poa_2022  Ins_Cap_Sep_2022  solar_2022  Net_Load_2022  \
# ...

# %%
# Convert 'Hour' column to proper time format
df4.index = pd.to_datetime(df4["time"], format='%H:%M:%S')

fig, ax = plt.subplots(figsize=(10, 5))

plt.plot(df4.index, df4["Net_Load_2020"], label="2020", color="black", marker="P", linestyle="-")
plt.plot(df4.index, df4["Net_Load_2021"], label="2021", color="yellow", marker="x", linestyle="-")
plt.plot(df4.index, df4["Net_Load_2022"], label="2022", color="blue", marker="o", linestyle="-")
plt.plot(df4.index, df4["Net_Load_2023"], label="2023", color="red", marker="s", linestyle="-")

date_form = DateFormatter('%H:%M')
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.HourLocator(interval=2))

# Formatting the plot
plt.xlabel("Hour of the Day", fontsize=12)
plt.ylabel("Net Load (MW)", fontsize=12)
plt.title("Duck Curve for India (Post- Monsoon season)", fontsize=16, weight= "bold")
#plt.xticks(range(0, 24, 1))
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.show()
